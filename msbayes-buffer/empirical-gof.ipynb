# %%
# %load_ext rpy2.ipython

# %%
# %%R
# library(abc)

# %% [markdown]
# ## Get observed SS

# %%
# %%R
# FROG_OBS_FILE = "/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/conf/4frogs_obsSS.txt"
# FISH_OBS_FILE = "/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/conf/3fishes_obsSS.txt"
# frog_obs_ss = read.table(FROG_OBS_FILE, header=FALSE)
# print(frog_obs_ss)
# frog_obs_ss = frog_obs_ss[, 6:68]
# fish_obs_ss = read.table(FISH_OBS_FILE, header=FALSE)
# print(fish_obs_ss)
# fish_obs_ss = fish_obs_ss[, 6:68]
# Out:
#   V1 V2 V3 V4 V5       V6       V7       V8       V9     V10      V11      V12
# 1  9  1  0  1  0 0.038325 0.045067 0.060683 0.088415 0.00588 0.003753 0.005832
#       V13      V14      V15      V16      V17      V18      V19      V20
# 1 0.03939 0.013914 0.024545 0.033693 0.064531 0.020176 0.016397 0.023762
#        V21      V22      V23     V24      V25       V26      V27      V28
# 1 0.050942 0.032445 0.041314 0.05485 0.049024 -1.320088 2.088735 1.613516
#        V29      V30      V31      V32      V33      V34      V35      V36
# 1 1.223186 0.034498 0.033117 0.045257 0.052443 0.005819 0.000981 0.004275
#        V37      V38      V39      V40      V41      V42      V43     V44
# 1 0.023939 0.010638 0.004812 0.006689 0.044909 0.010856 0.001107 0.00726
#        V45      V46      V47      V48     V49      V50      V51      V52
# 1 0.027751 0.010638 0.005369 0.008044 0.03693 0.023786 0.005217 0.018739
#        V53 V54      V55      V56     V57      V58     V59      V60      V61
# ...

# %%
# %%R
# typeof(fish_obs_ss)
# tmp_obs_ss = fish_obs_ss[, 6:68]

# %%
# %%R
# fish_buffer0 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/3fishes_buffer0/all_pods.obs", header=FALSE)
# fish_buffer0.01 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/3fishes_buffer0.01/all_pods.obs", header=FALSE)
# fish_buffer0.05 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/3fishes_buffer0.05/all_pods.obs", header=FALSE)
# fish_buffer0.1 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/3fishes_buffer0.1/all_pods.obs", header=FALSE)
#
# fish_buffer0 = fish_buffer0[, 6:68]
# fish_buffer0.01 = fish_buffer0.01[, 6:68]
# fish_buffer0.05 = fish_buffer0.05[, 6:68]
# fish_buffer0.1 = fish_buffer0.1[, 6:68]

# %%
# %%R
#
# res = gfit(target=fish_obs_ss, sumstat=fish_buffer0, statistic=mean, nb.replicate=100)
# plot(res, main="Histogram under buffer 0")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.53
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   11.52   12.70   13.76   14.74   15.95   24.63
#
# $dist.obs
# [1] 13.61257

# %%
# %%R
#
# res = gfit(target=fish_obs_ss, sumstat=fish_buffer0.01, statistic=mean, nb.replicate=100)
# plot(res, main="Histogram under buffer 0.01")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.77
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   10.86   11.97   13.17   13.76   15.35   24.84
#
# $dist.obs
# [1] 11.91761

# %%
# %%R
#
# res = gfit(target=fish_obs_ss, sumstat=fish_buffer0.05, statistic=mean, nb.replicate=100)
# plot(res, main="Histogram under buffer 0.05")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.66
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   12.20   13.29   14.42   15.35   16.05   33.55
#
# $dist.obs
# [1] 13.57888

# %%
# %%R
#
# res = gfit(target=fish_obs_ss, sumstat=fish_buffer0.1, statistic=mean, nb.replicate=100)
# plot(res, main="Histogram under buffer 0.1")
# print(summary(res))

# %%
# %%R
# frog_buffer0 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/4frogs_buffer0/all_pods.obs", header=FALSE)
# frog_buffer0.01 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/4frogs_buffer0.01/all_pods.obs", header=FALSE)
# frog_buffer0.05 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/4frogs_buffer0.05/all_pods.obs", header=FALSE)
# frog_buffer0.1 = read.table("/Volumes/WorkDrive/msbayes-buffering/hickerlab-repository/msbayes-buffering/data/empirical/results/results-buffer/4frogs_buffer0.1/all_pods.obs", header=FALSE)
#
# frog_buffer0 = frog_buffer0[, 6:68]
# frog_buffer0.01 = frog_buffer0.01[, 6:68]
# frog_buffer0.05 = frog_buffer0.05[, 6:68]
# frog_buffer0.1 = frog_buffer0.1[, 6:68]

# %%
# %%R
#
# res = gfit(target=frog_obs_ss, sumstat=frog_buffer0, statistic=mean, nb.replicate=10)
# plot(res, main="Histogram under buffer 0")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.8
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   11.47   12.52   13.86   13.76   15.21   15.34
#
# $dist.obs
# [1] 12.26733

# %%
# %%R
#
# res = gfit(target=frog_obs_ss, sumstat=frog_buffer0.01, statistic=mean, nb.replicate=10)
# plot(res, main="Histogram under buffer 0.01")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.6
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   11.44   12.20   13.27   13.32   14.18   15.50
#
# $dist.obs
# [1] 12.5917

# %%
# %%R
#
# res = gfit(target=frog_obs_ss, sumstat=frog_buffer0.05, statistic=mean, nb.replicate=10)
# plot(res, main="Histogram under buffer 0.05")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.2
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   11.04   11.84   12.17   12.24   12.33   14.69
#
# $dist.obs
# [1] 12.41173

# %%
# %%R
#
# res = gfit(target=frog_obs_ss, sumstat=frog_buffer0.1, statistic=mean, nb.replicate=10)
# plot(res, main="Histogram under buffer 0.1")
# print(summary(res))
# Out:
# $pvalue
# [1] 0.3
#
# $s.dist.sim
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   10.75   11.30   11.74   12.12   12.78   14.04
#
# $dist.obs
# [1] 12.18466
